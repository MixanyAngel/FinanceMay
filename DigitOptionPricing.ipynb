# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import enum
from Py.BS import TypeOptionVanilla
import pandas as pd
from Py.Market import *
from Py.ResultSimulation import *
from Py.BlackScholes import *
from Py.Heston import *
from Py.CalibrationProduct import *
from Py.DigitOptionProduct import *

from Py.DigitOptionPricer import *
from Py.MCSensi import *

# %% [markdown]
# ### Create Market

# %%
spot = 100
marketObj = Market(spot)
marketObj.initBlack(r= 0.00,repo = 0.000,vol = 0.2)

# %% [markdown]
# ### Create Model for Pricing

# %%
hestonObj = Heston(marketObj,rho = -0.7,Vo = 0.2,nu=0.7)
bsModel = BlackScholesModel(marketObj,sigma= 0.2)

# %% [markdown]
# ##### Set For calibration

# %%
listK = [30,80,100,110,120]
listT = [1,2]
So = 100
listCalibrationProducts = []

for K in listK:
    
    sens = 1 if K <=So else -1
    for T in listT:        
        listCalibrationProducts.append(VanillaProduct(K,T,marketObj,sens))

# %%
hestonObj.calibrate(listCalibrationProducts,verbose=1,listParamToFix=[],maxIter=100)
# Out:
# The maximum number of function evaluations is exceeded.
# Number of iterations: 100, function evaluations: 714, CG iterations: 332, optimality: 8.52e-07, constraint violation: 0.00e+00, execution time: 4.1e+01 s.

# %%
hestonObj.printParams()
# Out:
# {'kappa': 4.193698665590299,
#  'theta': 0.04000256008482871,
#  'Vo': 0.040012620520357374,
#  'nu': 0.02914368208798201,
#  'rho': 0.0007301511621102556}

# %% [markdown]
# ##### Check Calibration

# %%
model = hestonObj

# %%
[((model.modelPrice(u)-u.value)/u.value)*10000 for u in listCalibrationProducts]
# Out:
# [3.0630482276908906e-08,
#  0.00010988578047619804,
#  0.13431455611764884,
#  0.05468509049351113,
#  -0.36332787757195595,
#  -0.149799582052823,
#  -0.04980615476729678,
#  -0.03412155957945579,
#  0.13945648105747438,
#  0.0630663647344224]

# %% [markdown]
# ### Create European Digit product and Price

# %%
spotRef = 100
maturity = 5
strike = 2
typeDigit = TypeDigit.European
hasRebate = False
rebateCpn = 0.0
Nominal = 100

# %%
digitOptionProduct = DigitOptionProduct(spotRef = spotRef,maturity = maturity,
                                            strike = strike,                                            
                                            typeDigit = typeDigit,                                            
                                            hasRebate = hasRebate,                                            
                                            Nominal = Nominal )

# %%
#listSpots=[0.1,0.2,0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2,1.3,1.4, 1.5,1.7,2,2.5,3]
sensiEngine = GenerateMCSensi(digitOptionProduct,DigitOptionPricer,bsModel,nbSim = 100000,discretStep = Frequency.Annualy)
resSensi = sensiEngine.runPriceAndGreeks(listSpots=[0.01,0.02,0.05,0.1,0.3,0.5, 0.7, 1.0,1.2,1.4,1.7,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5])
mcSensiPlot(resSensi)
# Out:
# 0.01 is being treated
# 0.02 is being treated
# 0.05 is being treated
# 0.1 is being treated
# 0.3 is being treated
# 0.5 is being treated
# 0.7 is being treated
# 1.0 is being treated
# 1.2 is being treated
# 1.4 is being treated
# 1.7 is being treated
# 2 is being treated
# 2.5 is being treated
# 3 is being treated
# 3.5 is being treated
# 4 is being treated
# 4.5 is being treated
# 5 is being treated
# 5.5 is being treated
# 6 is being treated
# 6.5 is being treated
# 7 is being treated
# 7.5 is being treated
# 8 is being treated
# 8.5 is being treated
# 13.455270767211914
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
sensiEngine.refPrice
# Out:
# 3.836

# %% [markdown]
# ### Create American Digit product and Price

# %%
spotRef = 100
maturity = 5
strike = 2
typeDigit = TypeDigit.American
hasRebate = False
rebateCpn = 0.0
Nominal = 100

# %%
digitOptionProduct = DigitOptionProduct(spotRef = spotRef,maturity = maturity,
                                            strike = strike,                                            
                                            typeDigit = typeDigit,                                            
                                            hasRebate = hasRebate,                                            
                                            Nominal = Nominal )

# %%
#listSpots=[0.1,0.2,0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2,1.3,1.4, 1.5,1.7,2,2.5,3]
sensiEngineAmer = GenerateMCSensi(digitOptionProduct,DigitOptionPricer,bsModel,nbSim = 10000,discretStep = Frequency.TriDaily)
resSensiAmer = sensiEngineAmer.runPriceAndGreeks(listSpots=[0.01,0.02,0.05,0.1,0.3,0.5, 0.7, 1.0,1.2,1.4,1.7,2,2.5,3,3.5,4])
mcSensiPlot(resSensiAmer)
# Out:
# 0.01 is being treated
# 0.02 is being treated
# 0.05 is being treated
# 0.1 is being treated
# 0.3 is being treated
# 0.5 is being treated
# 0.7 is being treated
# 1.0 is being treated
# 1.2 is being treated
# 1.4 is being treated
# 1.7 is being treated
# 2 is being treated
# 2.5 is being treated
# 3 is being treated
# 3.5 is being treated
# 4 is being treated
# 695.0735030174255

# %%
sensiEngineAmer.refPrice
# Out:
# 8.28
